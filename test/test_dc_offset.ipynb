# %%
import sys
# You have to use the path of the project folder to access the filters module
sys.path.append('../')

# %%
import filters as f
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate random data between 0 and 1
data = np.random.randint(0,2,size=(1,1,250))

# %%
k = f.apply_dc_offset(data)

# %%
fig,ax=plt.subplots(2,figsize=(13,8))
fig.subplots_adjust(hspace=0.5)
ax[0].plot(data.reshape(-1))
ax[1].plot(k.reshape(-1))
ax[0].set_title('Orginal Data')
ax[1].set_title('DC offset Data')
# Out:
# Text(0.5, 1.0, 'DC offset Data')
