# %%
import sys
sys.path.append('../')

# %%
from imports import *

# %%
import config
import data as d
# Out:
# Using config.dataReader - random number

# %%
path = Path('../test_data/raghav_game')
_data = d.load_all_pickle_files(path,vstack=True)
# Out:
# Loading data from ../test_data/raghav_game
# First 10 epochs will be removed while loading the data.
# Loading File: [f]raghav_game_eyes_closed|301019_135051.pickle
# Using vstack=True

# %%
_data_new = _data.transpose(0,2,1).reshape(-1,8)

# %%
_data_new = _data_new - _data_new.mean(axis=0)
_data_new = _data_new/_data_new.std(axis=0)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=7)

# %%
_out_data = pca.fit_transform(_data_new[:,0:-1])

# %%
fig, ax = plt.subplots(7,1,figsize=(5,20))
for i in range(7):
    ax[i].plot(_out_data[:,i].reshape(-1))

# %%
_data_new.std()
# Out:
# 82.44496697408248
