# %% [markdown]
# # This notebook is to compare metrics between different actions like eyes closed and play_game

# %%
import sys
sys.path.append('../')

# %%
from data import *
# Out:
# Using config.dataReader - random number

# %%
path_1 = '../test_data/sashi_eyes_closed//'
path_2 = '../test_data/sashi_work/'

# %%
data_1 = get_attention_metric(path_1)
# Out:
# Loading data from ../test_data/sashi_eyes_closed
# First 10 epochs will be removed while loading the data.
# Loading File: [f]sashi_EYES_CLOSED|171019_172659.pickle
# Loading File: [f]sashi_EYES_CLOSED|181019_164552.pickle
# Loading File: [f]sashi_eyes_closed|151019_135421.pickle
# Loading File: [f]sashi_EYES_CLOSED|181019_163555.pickle
# Using vstack=True
# Processing file:1
# Clean data shape:(3338, 8, 250)
# Processing file:1
# /usr/lib/python3.7/site-packages/scipy/signal/spectral.py:1969: UserWarning: nperseg = 500 is greater than input length  = 250, using nperseg = 250
#   .format(nperseg, input_length))

# %%
data_2 = get_attention_metric(path_2)
# Out:
# Loading data from ../test_data/sashi_work
# First 10 epochs will be removed while loading the data.
# Loading File: [f]sashi_assignment|151019_140830.pickle
# Loading File: [f]sashi_ATTENTION|171019_173817.pickle
# Loading File: [f]sashi_ATTENTION|181019_145457.pickle
# Loading File: [f]sashi_ATTENTION|181019_144315.pickle
# Using vstack=True
# Processing file:1
# Clean data shape:(4215, 8, 250)
# Processing file:1

# %%
compare_metrics(data_1,data_2,channels=[0,1,6,7],labels=['eyes_closed','game'])
